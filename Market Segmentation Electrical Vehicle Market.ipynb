# %% [markdown]
# ### Market Segmentation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
ev=pd.read_csv(r"C:\Users\Admin\Desktop\Feynn labs\Project 3\Market Segmentation EV\Indian automoble buying behavour study 1.0.csv")

# %%
ev.head()
# Out:
#    Age Profession Marrital Status      Education  No of Dependents  \
# 0   27   Salaried          Single  Post Graduate                 0
# 1   35   Salaried         Married  Post Graduate                 2
# 2   45   Business         Married       Graduate                 4
# 3   41   Business         Married  Post Graduate                 3
# 4   31   Salaried         Married  Post Graduate                 2
#
#   Personal loan House Loan Wife Working   Salary  Wife Salary  Total Salary  \
# 0           Yes         No           No   800000            0        800000
# 1           Yes        Yes          Yes  1400000       600000       2000000
# 2           Yes        Yes           No  1800000            0       1800000
# 3            No         No          Yes  1600000       600000       2200000
# 4           Yes         No          Yes  1800000       800000       2600000
#
#      Make    Price
# 0     i20   800000
# 1    Ciaz  1000000
# 2  Duster  1200000
# 3    City  1200000
# ...

# %%
ev.shape
# Out:
# (99, 13)

# %%
ev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               99 non-null     int64
#  1   Profession        99 non-null     object
#  2   Marrital Status   99 non-null     object
#  3   Education         99 non-null     object
#  4   No of Dependents  99 non-null     int64
#  5   Personal loan     99 non-null     object
#  6   House Loan        99 non-null     object
#  7   Wife Working      99 non-null     object
#  8   Salary            99 non-null     int64
#  9   Wife Salary       99 non-null     int64
#  10  Total Salary      99 non-null     int64
#  11  Make              99 non-null     object
#  12  Price             99 non-null     int64
# dtypes: int64(6), object(7)
# memory usage: 10.2+ KB

# %%
ev.describe()
# Out:
#              Age  No of Dependents        Salary   Wife Salary  Total Salary  \
# count  99.000000         99.000000  9.900000e+01  9.900000e+01  9.900000e+01
# mean   36.313131          2.181818  1.736364e+06  5.343434e+05  2.270707e+06
# std     6.246054          1.335265  6.736217e+05  6.054450e+05  1.050777e+06
# min    26.000000          0.000000  2.000000e+05  0.000000e+00  2.000000e+05
# 25%    31.000000          2.000000  1.300000e+06  0.000000e+00  1.550000e+06
# 50%    36.000000          2.000000  1.600000e+06  5.000000e+05  2.100000e+06
# 75%    41.000000          3.000000  2.200000e+06  9.000000e+05  2.700000e+06
# max    51.000000          4.000000  3.800000e+06  2.100000e+06  5.200000e+06
#
#               Price
# count  9.900000e+01
# mean   1.194040e+06
# std    4.376955e+05
# min    1.100000e+05
# 25%    8.000000e+05
# 50%    1.200000e+06
# 75%    1.500000e+06
# max    3.000000e+06

# %%
ev.columns
# Out:
# Index(['Age', 'Profession', 'Marrital Status', 'Education', 'No of Dependents',
#        'Personal loan', 'House Loan', 'Wife Working', 'Salary', 'Wife Salary',
#        'Total Salary', 'Make', 'Price'],
#       dtype='object')

# %%
ev.nunique()
# Out:
# Age                 22
# Profession           2
# Marrital Status      2
# Education            2
# No of Dependents     4
# Personal loan        2
# House Loan           2
# Wife Working         3
# Salary              24
# Wife Salary         14
# Total Salary        36
# Make                 9
# Price               10
# dtype: int64

# %%
ev.isna().sum()
# Out:
# Age                 0
# Profession          0
# Marrital Status     0
# Education           0
# No of Dependents    0
# Personal loan       0
# House Loan          0
# Wife Working        0
# Salary              0
# Wife Salary         0
# Total Salary        0
# Make                0
# Price               0
# dtype: int64

# %%
ev.loc[ev['Wife Working'] == 'm']
# Out:
#     Age Profession Marrital Status Education  No of Dependents Personal loan  \
# 11   35   Salaried         Married  Graduate                 4           Yes
#
#    House Loan Wife Working   Salary  Wife Salary  Total Salary    Make   Price
# 11        Yes            m  1400000            0       1400000  Baleno  700000

# %%
ev=ev.replace(to_replace ="m", value ="No")
ev.loc[11]
# Out:
# Age                       35
# Profession          Salaried
# Marrital Status      Married
# Education           Graduate
# No of Dependents           4
# Personal loan            Yes
# House Loan               Yes
# Wife Working              No
# Salary               1400000
# Wife Salary                0
# Total Salary         1400000
# Make                  Baleno
# Price                 700000
# Name: 11, dtype: object

# %%
plt.figure(1, figsize=(15, 7))
n = 0
colors = ["#FF0000", "#00FF00", "#0000FF", "#FFFF00", "#00FFFF", "#FF00FF"]  # Example color palette
for cols in ['Age', 'No of Dependents', 'Salary', 'Wife Salary', 'Total Salary', 'Price']:
    n += 1
    plt.subplot(1, 6, n)
    sns.set(style='whitegrid')
    plt.subplots_adjust(hspace=0.5, wspace=0.5)
    sns.violinplot(x=cols, y='Make', data=ev, palette=colors)  # Set the color palette
    plt.ylabel("Make" if n == 1 else '')
    plt.title('Violin Plot')

# %%
plt.figure(1,figsize=(15,7))
n = 0
for cols in ['Age','No of Dependents','Salary','Wife Salary','Total Salary','Price']:
  n += 1
  plt.subplot(1,6,n)
  sns.set(style = 'whitegrid')
  plt.subplots_adjust(hspace=0.5,wspace=0.5)
  sns.violinplot(x= cols, y = 'Make', data=ev)
  plt.ylabel("Make" if n==1 else '')
  plt.title('Violin Plot')

# %% [markdown]
# ### Age: Younger consumers tend to opt for more affordable vehicles.
# ### Number of Dependents: Consumers with a larger number of dependents show a preference for vehicles with additional seating capacity, often leaning towards SUVs.
# ### Salary: When comparing the normalized salary distribution with the price plot, it becomes evident that the median of the salary violin plot closely aligns with the median price of the vehicles, indicating a strong and direct relationship.

# %%
sns.set_theme(style="ticks", palette=None)
plt.figure(figsize=(20, 6))
sns.countplot(x="Make", data=ev, hue="Age")
plt.legend(loc='upper right')  # Change the legend position to upper right

# %%
sns.set_theme(style="ticks", palette=None)
plt.figure(figsize=(20,6))
sns.countplot(x="Make", data=ev, hue="Age")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
plt.xlabel('Age')
plt.ylabel('Price of car owned')
plt.scatter(ev['Age'],ev['Price'])

# %%
plt.figure(figsize=(20,6))
sns.countplot(x="Make", data=ev, hue="Total Salary")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
plt.xlabel('total salary')
plt.ylabel('Price of car owned')
plt.scatter(ev['Total Salary'],ev['Price'])

# %%
plt.figure(figsize=(20,6))
sns.countplot(x="Make", data=ev, hue="No of Dependents")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
plt.xlabel('No of Dependents')
plt.ylabel('Price of car owned')
plt.scatter(ev['No of Dependents'],ev['Price'])

# %%
sns.set_theme(style="ticks", palette=None)
plt.figure(figsize=(20, 6))
sns.countplot(x="Make", data=ev, hue="Age")
plt.legend(loc='upper right')  # Change the legend position to upper right

# %%
plt.figure(figsize=(20, 6))
custom_palette = ["#FF0000", "#00FF00", "#0000FF"]  # Example custom color palette
sns.countplot(x="Make", data=ev, hue="Marrital Status", palette=custom_palette)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
plt.figure(figsize=(20,6))
sns.countplot(x="Make", data=ev, hue="Marrital Status")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
plt.xlabel('Marital Status')
plt.ylabel('Price of Car Owned')
plt.scatter(ev['Marrital Status'], ev['Price'], color='blue', alpha=0.5)  # Change the plot to a scatter plot and set color and transparency
plt.show()

# %%
plt.xlabel('Marrital Status')
plt.ylabel('Price of car owned')
plt.scatter(ev['Marrital Status'],ev['Price'])

# %%
plt.figure(figsize=(20,6))
sns.countplot(x="Make", data=ev, hue="Profession")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
plt.figure(figsize=(8, 8))  # Adjust the figure size for a circular plot
profession_counts = ev['Profession'].value_counts()
plt.pie(profession_counts, labels=profession_counts.index, autopct='%1.1f%%', startangle=90)
plt.axis('equal')  # Ensure the pie chart is circular
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
plt.xlabel('Profession')
plt.ylabel('Price of car owned')
plt.scatter(ev['Profession'],ev['Price'])

# %%
plt.figure(figsize=(20, 6))
custom_palette = ["#FF0000", "#00FF00", "#0000FF"]  # Example custom color palette
sns.countplot(x="Make", data=ev, hue="Education", palette=custom_palette)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
# Set the color palette
sns.set_palette("deep")

# Your plotting code using Seaborn
sns.countplot(x="Make", data=ev, hue="Education")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
plt.figure(figsize=(20,6))
sns.countplot(x="Make", data=ev, hue="Education")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
plt.xlabel('Education')
plt.ylabel('Price of car owned')
plt.scatter(ev['Education'],ev['Price'])

# %%
plt.figure(figsize=(20,6))
sns.countplot(x="Make", data=ev, hue="Personal loan")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
plt.figure(figsize=(20, 6))
custom_palette = ["#0000FF", "#00FF00"]  # Example custom color palette
sns.countplot(x="Make", data=ev, hue="Personal loan", palette=custom_palette)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
plt.xlabel('Personal loan')
plt.ylabel('Price of car owned')
plt.scatter(ev['Personal loan'],ev['Price'])

# %%
plt.figure(figsize=(20, 6))
custom_palette = ["#66BB55", "#006600", "#660033"]  # Example custom color palette
sns.countplot(x="Make", data=ev, hue="House Loan", palette=custom_palette)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
plt.figure(figsize=(20,6))
sns.countplot(x="Make", data=ev, hue="House Loan")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
plt.xlabel('House Loan')
plt.ylabel('Price of car owned')
plt.scatter(ev['House Loan'],ev['Price'])

# %%
plt.figure(1, figsize=(15, 6))
n = 0
custom_colors = ["#FF0000", "#00FF00", "#0000FF", "#FF00FF", "#FFFF00", "#00FFFF"]  # Example custom color pattern
for x in ['Age', 'No of Dependents', 'Salary', 'Wife Salary', 'Total Salary', 'Price']:
    n += 1
    plt.subplot(1, 6, n)
    plt.subplots_adjust(hspace=0.5, wspace=0.5)
    sns.distplot(ev[x], bins=20, color=custom_colors[n-1])
    plt.title('Distplot of {}'.format(x))
plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Plotting for int64 dtype columns
plt.figure(1, figsize=(15,6))
n=0
for x in ['Age', 'No of Dependents' ,'Salary'  ,'Wife Salary'  ,'Total Salary'  ,'Price']:
  n += 1
  plt.subplot(1,6,n)
  plt.subplots_adjust(hspace=0.5, wspace=0.5)
  sns.distplot(ev[x], bins = 20)
  plt.title('Distplot of {}'.format(x))
plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ### Observations
# ### The consumer market is primarily dominated by individuals aged between 25 and 50.
# ### Individuals with an average total salary of approximately 30 lakhs are more inclined to purchase vehicles.
# ### The majority of people allocate a budget of 10 to 20 lakhs for vehicle purchases.

# %%
# Heatmap of Correlation
sns.heatmap(ev.corr(), annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
# Pair Plot
sns.pairplot(ev)

# %% [markdown]
# ### Geographic Analysis

# %%
# Importing state-wise sales dataset
df=pd.read_csv(r"C:\Users\Admin\Desktop\Feynn labs\Project 3\Market-Segmentation-for-Electric-Vehicles-in-India-main\EVStats.csv")

# %%
df.head()
# Out:
#    Sl. No                      State  \
# 0       1                  Meghalaya
# 1       2                   Nagaland
# 2       3                    Manipur
# 3       4                    Tripura
# 4       5  Andaman & Nicobar islands
#
#    Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules  \
# 0                                                  0
# 1                                                  0
# 2                                                 16
# 3                                                 28
# 4                                                  0
#
#    Two Wheelers (Category L2 (CMVR))  \
# 0                                  0
# 1                                 20
# 2                                  8
# 3                                  9
# 4                                  0
#
#    Two Wheelers (Max power not exceeding 250 Watts)  \
# 0                                                 0
# 1                                                 3
# ...

# %%
df.tail()
# Out:
#     Sl. No          State  \
# 25      26          Delhi
# 26      27        Haryana
# 27      28  Uttar Pradesh
# 28      29        Gujarat
# 29      30    Maharashtra
#
#     Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules  \
# 25                                               1395
# 26                                               3162
# 27                                               2954
# 28                                               7182
# 29                                               2630
#
#     Two Wheelers (Category L2 (CMVR))  \
# 25                                251
# 26                               1504
# 27                               2355
# 28                                217
# 29                               2097
#
#     Two Wheelers (Max power not exceeding 250 Watts)  \
# 25                                              5018
# 26                                             13908
# 27                                             15199
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 10 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Sl. No                                                              30 non-null     int64
#  1   State                                                               30 non-null     object
#  2   Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules  30 non-null     int64
#  3   Two Wheelers (Category L2 (CMVR))                                   30 non-null     int64
#  4   Two Wheelers (Max power not exceeding 250 Watts)                    30 non-null     int64
#  5   Three Wheelers (Category L5 slow speed as per CMVR)                 30 non-null     int64
#  6   Three Wheelers (Category L5 as per CMVR)                            30 non-null     int64
# ...

# %%
df.shape
# Out:
# (30, 10)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming `df` is your DataFrame containing the data

# Define the categories
categories = [
    'Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules',
    'Two Wheelers (Category L2 (CMVR))',
    'Two Wheelers (Max power not exceeding 250 Watts)',
    'Three Wheelers (Category L5 slow speed as per CMVR)',
    'Three Wheelers (Category L5 as per CMVR)',
    'Passenger Cars (Category M1 as per CMVR)',
    'Buses',
    'Total in state'
]

# Create a figure and axes
fig, ax = plt.subplots()

# Iterate over the categories
for category in categories:
    # Sort the DataFrame by the current category and get the top 5 states
    top_states = df.sort_values(category, ascending=True).tail(5)

    # Plot the horizontal bar chart for the current category
    ax.barh(top_states['State'], top_states[category], label=category)

# Set the title and labels
ax.set_title('Top 5 States for Each Category of Electric Vehicles')
ax.set_xlabel('Number of Electric Vehicles')
ax.set_ylabel('State')

# Adjust the layout to avoid label overlap
plt.tight_layout()

# Display the legend
ax.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming `df` is your DataFrame containing the data

# Define the categories
categories = [
    'Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules',
    'Two Wheelers (Category L2 (CMVR))',
    'Two Wheelers (Max power not exceeding 250 Watts)',
    'Three Wheelers (Category L5 slow speed as per CMVR)',
    'Three Wheelers (Category L5 as per CMVR)',
    'Passenger Cars (Category M1 as per CMVR)',
    'Buses',
    'Total in state'
]

# Calculate the number of rows and columns for the subplots
num_rows = (len(categories) - 1) // 2 + 1
num_cols = min(2, len(categories))

# Create the subplots
fig, axs = plt.subplots(num_rows, num_cols, figsize=(12, 8))

# Iterate over the categories and corresponding subplots
for i, category in enumerate(categories):
    # Calculate the subplot indices
    row = i // num_cols
    col = i % num_cols

    # Sort the DataFrame by the current category and get the top 5 states
    top_states = df.sort_values(category, ascending=True).tail(5)

    # Plot the horizontal bar chart for the current category in the corresponding subplot
    axs[row, col].barh(top_states['State'], top_states[category])
    axs[row, col].set_title(category)

# Adjust the layout to avoid overlap
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Top 5 states for each category of Electric Vehicles
for y in ['Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules','Two Wheelers (Category L2 (CMVR))','Two Wheelers (Max power not exceeding 250 Watts)','Three Wheelers (Category L5 slow speed as per CMVR)','Three Wheelers (Category L5 as per CMVR)','Passenger Cars (Category M1 as per CMVR)','Buses','Total in state']:
  ax = df.sort_values(y, ascending=True).tail(5).plot.barh(x='State', y=y)

# %% [markdown]
# ### Model Deployment¶
# ### K-Means Clustering

# %%
X = ev.iloc[:,ev.columns!='Make']
X.head()
# Out:
#    Age Profession Marrital Status      Education  No of Dependents  \
# 0   27   Salaried          Single  Post Graduate                 0
# 1   35   Salaried         Married  Post Graduate                 2
# 2   45   Business         Married       Graduate                 4
# 3   41   Business         Married  Post Graduate                 3
# 4   31   Salaried         Married  Post Graduate                 2
#
#   Personal loan House Loan Wife Working   Salary  Wife Salary  Total Salary  \
# 0           Yes         No           No   800000            0        800000
# 1           Yes        Yes          Yes  1400000       600000       2000000
# 2           Yes        Yes           No  1800000            0       1800000
# 3            No         No          Yes  1600000       600000       2200000
# 4           Yes         No          Yes  1800000       800000       2600000
#
#      Price
# 0   800000
# 1  1000000
# 2  1200000
# 3  1200000
# 4  1600000

# %%
encoding = {"Profession":{"Salaried": 0, "Business": 1},
            "Marrital Status":{"Single": 0, "Married": 1},
            "Education":{"Graduate": 0, "Post Graduate": 1},
            "Personal loan":{"No": 0, "Yes": 1},
            "House Loan":{"No": 0, "Yes": 1},
            "Wife Working":{"No": 0, "Yes": 1}
            }

# %%
obj_df = X.replace(encoding)
obj_df.head()
# Out:
#    Age  Profession  Marrital Status  Education  No of Dependents  \
# 0   27           0                0          1                 0
# 1   35           0                1          1                 2
# 2   45           1                1          0                 4
# 3   41           1                1          1                 3
# 4   31           0                1          1                 2
#
#    Personal loan  House Loan  Wife Working   Salary  Wife Salary  \
# 0              1           0             0   800000            0
# 1              1           1             1  1400000       600000
# 2              1           1             0  1800000            0
# 3              0           0             1  1600000       600000
# 4              1           0             1  1800000       800000
#
#    Total Salary    Price
# 0        800000   800000
# 1       2000000  1000000
# 2       1800000  1200000
# 3       2200000  1200000
# 4       2600000  1600000

# %%
print(obj_df.dtypes)
# Out:
# Age                 int64
# Profession          int64
# Marrital Status     int64
# Education           int64
# No of Dependents    int64
# Personal loan       int64
# House Loan          int64
# Wife Working        int64
# Salary              int64
# Wife Salary         int64
# Total Salary        int64
# Price               int64
# dtype: object

# %%
# Importing Important Libraries
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
X_scaled = StandardScaler().fit_transform(obj_df)
X_scaled = pd.DataFrame(X_scaled,columns=['Age', 'Profession', 'Marrital Status', 'Education', 'No of Dependents',
                                          'Personal loan', 'House Loan', 'Wife Working', 'Salary', 'Wife Salary',
                                          'Total Salary','Price'])
x = X_scaled.to_numpy()
X_scaled
# Out:
#          Age  Profession  Marrital Status  Education  No of Dependents  \
# 0  -1.498630   -0.739510        -2.366432   0.876275         -1.642313
# 1  -0.211304   -0.739510         0.422577   0.876275         -0.136859
# 2   1.397855    1.352247         0.422577  -1.141195          1.368594
# 3   0.754191    1.352247         0.422577   0.876275          0.615867
# 4  -0.854967   -0.739510         0.422577   0.876275         -0.136859
# ..       ...         ...              ...        ...               ...
# 94 -1.498630    1.352247        -2.366432  -1.141195         -1.642313
# 95  2.202434   -0.739510         0.422577   0.876275          0.615867
# 96  2.363350    1.352247         0.422577  -1.141195         -0.136859
# 97  2.363350   -0.739510         0.422577   0.876275         -0.136859
# 98  2.363350   -0.739510         0.422577   0.876275         -0.136859
#
#     Personal loan  House Loan  Wife Working    Salary  Wife Salary  \
# ...

# %%
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', 
                    max_iter = 300, n_init = 10,random_state = 0)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
plt.plot(range(1, 11), wcss)
plt.title('Elbow Method Plot')
plt.xlabel('Number of Clusters')
plt.ylabel('Within-Cluster Sum of Square') # Within cluster sum of squares
plt.tight_layout()
plt.show()

# %% [markdown]
# ### K = 3

# %%
kmeans = KMeans(n_clusters = 3, init = 'k-means++', 
                    max_iter = 300, n_init = 10,random_state = 42)
kmeans.fit(X_scaled)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
y = kmeans.predict(X_scaled)
y_df = pd.DataFrame(y,columns=['Class'])

# %%
final_data = pd.concat([ev,y_df],axis=1) 
final_data
# Out:
#     Age Profession Marrital Status      Education  No of Dependents  \
# 0    27   Salaried          Single  Post Graduate                 0
# 1    35   Salaried         Married  Post Graduate                 2
# 2    45   Business         Married       Graduate                 4
# 3    41   Business         Married  Post Graduate                 3
# 4    31   Salaried         Married  Post Graduate                 2
# ..  ...        ...             ...            ...               ...
# 94   27   Business          Single       Graduate                 0
# 95   50   Salaried         Married  Post Graduate                 3
# 96   51   Business         Married       Graduate                 2
# 97   51   Salaried         Married  Post Graduate                 2
# 98   51   Salaried         Married  Post Graduate                 2
#
#    Personal loan House Loan Wife Working   Salary  Wife Salary  Total Salary  \
# ...

# %%
sns.pairplot(final_data,x_vars = ['Age','Salary', 'Wife Salary','Total Salary','Price'], y_vars = ['Age','Salary', 'Wife Salary','Total Salary','Price'], hue='Class')

# %% [markdown]
# ### K=5

# %%
kmeans1 = KMeans(n_clusters = 5, init = 'k-means++', 
                    max_iter = 300, n_init = 10,random_state = 42)
kmeans1.fit(X_scaled)
# Out:
# KMeans(n_clusters=5, random_state=42)

# %%
y1 = kmeans1.predict(X_scaled)
y1_df = pd.DataFrame(y1,columns=['Class'])

# %%
final_data1 = pd.concat([ev,y1_df],axis=1) 
final_data1
# Out:
#     Age Profession Marrital Status      Education  No of Dependents  \
# 0    27   Salaried          Single  Post Graduate                 0
# 1    35   Salaried         Married  Post Graduate                 2
# 2    45   Business         Married       Graduate                 4
# 3    41   Business         Married  Post Graduate                 3
# 4    31   Salaried         Married  Post Graduate                 2
# ..  ...        ...             ...            ...               ...
# 94   27   Business          Single       Graduate                 0
# 95   50   Salaried         Married  Post Graduate                 3
# 96   51   Business         Married       Graduate                 2
# 97   51   Salaried         Married  Post Graduate                 2
# 98   51   Salaried         Married  Post Graduate                 2
#
#    Personal loan House Loan Wife Working   Salary  Wife Salary  Total Salary  \
# ...

# %%
sns.pairplot(final_data1,x_vars = ['Age','Salary', 'Wife Salary','Total Salary','Price'], y_vars = ['Age','Salary', 'Wife Salary','Total Salary','Price'], hue='Class')
